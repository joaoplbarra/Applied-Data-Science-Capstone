# %%
import pandas as pd
import numpy as py
df = pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv',low_memory=False)

# %%
df_new=df[['SEVERITYCODE','WEATHER','ROADCOND','COLLISIONTYPE','LIGHTCOND','VEHCOUNT']]
df_new.head()
# Out:
#    SEVERITYCODE   WEATHER ROADCOND COLLISIONTYPE                LIGHTCOND  \
# 0             2  Overcast      Wet        Angles                 Daylight
# 1             1   Raining      Wet     Sideswipe  Dark - Street Lights On
# 2             1  Overcast      Dry    Parked Car                 Daylight
# 3             1     Clear      Dry         Other                 Daylight
# 4             2   Raining      Wet        Angles                 Daylight
#
#    VEHCOUNT
# 0         2
# 1         2
# 2         3
# 3         3
# 4         2

# %%
print(df_new['WEATHER'].value_counts())
# Out:
# Clear                       111135
# Raining                      33145
# Overcast                     27714
# Unknown                      15091
# Snowing                        907
# Other                          832
# Fog/Smog/Smoke                 569
# Sleet/Hail/Freezing Rain       113
# Blowing Sand/Dirt               56
# Severe Crosswind                25
# Partly Cloudy                    5
# Name: WEATHER, dtype: int64

# %%
encoding_weather = {"WEATHER": 
                            {"Clear": 1,
                             "Raining": 2,
                             "Overcast": 3,
                             "Unknown": 4,
                             "Snowing": 5,
                             "Other": 6,
                             "Fog/Smog/Smoke": 7,
                             "Sleet/Hail/Freezing Rain": 8,
                             "Blowing Sand/Dirt": 9,
                            "Severe Crosswind": 10,
                             "Partly Cloudy": 11,
                             "Data missing or out of range": 6 }}
df_new.replace(encoding_weather, inplace=True)
df_new['WEATHER'].value_counts()
# Out:
# 1     111135
# 2      33145
# 3      27714
# 4      15091
# 5        907
# 6        832
# 7        569
# 8        113
# 9         56
# 10        25
# 11         5
# Name: WEATHER, dtype: int64

# %%
print(df_new['ROADCOND'].value_counts())
# Out:
# Dry               124510
# Wet                47474
# Unknown            15078
# Ice                 1209
# Snow/Slush          1004
# Other                132
# Standing Water       115
# Sand/Mud/Dirt         75
# Oil                   64
# Name: ROADCOND, dtype: int64

# %%
encoding_road = {"ROADCOND": 
                            {"Dry": 1,
                             "Wet": 2,
                             "Unknown": 3,
                             "Ice": 4,
                             "Snow/Slush": 5,
                             "Other": 6,
                             "Standing Water": 7,
                             "Sand/Mud/Dirt": 8,
                             "Oil": 9,
                             "Data missing or out of range": 6 }}
df_new.replace(encoding_road, inplace=True)
df_new['ROADCOND'].value_counts()
# Out:
# 1    124510
# 2     47474
# 3     15078
# 4      1209
# 5      1004
# 6       132
# 7       115
# 8        75
# 9        64
# Name: ROADCOND, dtype: int64

# %%
print(df_new['COLLISIONTYPE'].value_counts())
# Out:
# Parked Car    47987
# Angles        34674
# Rear Ended    34090
# Other         23703
# Sideswipe     18609
# Left Turn     13703
# Pedestrian     6608
# Cycles         5415
# Right Turn     2956
# Head On        2024
# Name: COLLISIONTYPE, dtype: int64

# %%
encoding_type = {"COLLISIONTYPE": 
                            {"Parked Car": 1,
                             "Angles": 2,
                             "Rear Ended": 3,
                             "Other": 4,
                             "Sideswipe": 5,
                             "Left Turn": 6,
                             "Pedestrian": 7,
                             "Cycles": 8,
                             "Right Turn": 9,
                             "Head On": 10,
                             "Data missing or out of range": 4 }}
df_new.replace(encoding_type, inplace=True)
df_new['COLLISIONTYPE'].value_counts()
# Out:
# 1     47987
# 2     34674
# 3     34090
# 4     23703
# 5     18609
# 6     13703
# 7      6608
# 8      5415
# 9      2956
# 10     2024
# Name: COLLISIONTYPE, dtype: int64

# %%
encoding_type = {"COLLISIONTYPE": 
                            {"Parked Car": 1,
                             "Angles": 2,
                             "Rear Ended": 3,
                             "Other": 4,
                             "Sideswipe": 5,
                             "Left Turn": 6,
                             "Pedestrian": 7,
                             "Cycles": 8,
                             "Right Turn": 9,
                             "Head On": 10,
                             "Data missing or out of range": 4 }}
df_new.replace(encoding_type, inplace=True)
df_new['COLLISIONTYPE'].value_counts()
# Out:
# 1     47987
# 2     34674
# 3     34090
# 4     23703
# 5     18609
# 6     13703
# 7      6608
# 8      5415
# 9      2956
# 10     2024
# Name: COLLISIONTYPE, dtype: int64

# %%
print(df_new['LIGHTCOND'].value_counts())
# Out:
# Daylight                    116137
# Dark - Street Lights On      48507
# Unknown                      13473
# Dusk                          5902
# Dawn                          2502
# Dark - No Street Lights       1537
# Dark - Street Lights Off      1199
# Other                          235
# Dark - Unknown Lighting         11
# Name: LIGHTCOND, dtype: int64

# %%
encoding_light = {"LIGHTCOND": 
                            {"Daylight": 1,
                             "Dark - Street Lights On": 2,
                             "Unknown": 3,
                             "Dusk": 4,
                             "Dawn": 5,
                             "Dark - No Street Lights": 6,
                             "Dark - Street Lights Off": 7,
                             "Other": 8,
                             "Dark - Unknown Lighting": 9,
                             "Data missing or out of range": 8 }}
df_new.replace(encoding_light, inplace=True)
df_new['LIGHTCOND'].value_counts()
# Out:
# 1    116137
# 2     48507
# 3     13473
# 4      5902
# 5      2502
# 6      1537
# 7      1199
# 8       235
# 9        11
# Name: LIGHTCOND, dtype: int64

# %%
df_new.dtypes
# Out:
# SEVERITYCODE      int64
# WEATHER          object
# ROADCOND         object
# COLLISIONTYPE    object
# LIGHTCOND        object
# VEHCOUNT          int64
# dtype: object

# %%
df_new.head()
# Out:
#    SEVERITYCODE WEATHER ROADCOND COLLISIONTYPE LIGHTCOND  VEHCOUNT
# 0             2       3        2             2         1         2
# 1             1       2        2             5         2         2
# 2             1       3        1             1         1         3
# 3             1       1        1             4         1         3
# 4             2       2        2             2         1         2

# %%
df_new.astype(float)
df_new.dtypes
# Out:
# SEVERITYCODE      int64
# WEATHER          object
# ROADCOND         object
# COLLISIONTYPE    object
# LIGHTCOND        object
# VEHCOUNT          int64
# dtype: object

# %%
df_new.isnull().sum()
# Out:
# SEVERITYCODE        0
# WEATHER          5081
# ROADCOND         5012
# COLLISIONTYPE    4904
# LIGHTCOND        5170
# VEHCOUNT            0
# dtype: int64

# %%
df_data =df_new.dropna(axis=0)
df_data.isnull().sum()
# Out:
# SEVERITYCODE     0
# WEATHER          0
# ROADCOND         0
# COLLISIONTYPE    0
# LIGHTCOND        0
# VEHCOUNT         0
# dtype: int64

# %%
df_data.head()
# Out:
#    SEVERITYCODE WEATHER ROADCOND COLLISIONTYPE LIGHTCOND  VEHCOUNT
# 0             2       3        2             2         1         2
# 1             1       2        2             5         2         2
# 2             1       3        1             1         1         3
# 3             1       1        1             4         1         3
# 4             2       2        2             2         1         2

# %%
from sklearn import preprocessing
y=df_data['SEVERITYCODE'].values
X=df_data.drop(['SEVERITYCODE'],axis=1)
X = preprocessing.StandardScaler().fit(X).transform(X)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, object were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:4: DataConversionWarning: Data with input dtype int64, object were all converted to float64 by StandardScaler.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4 )
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (151452, 5) (151452,)
# Test set: (37864, 5) (37864,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
Ks = 10
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])
print('accuracy:',mean_acc)
print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1 )
# Out:
# accuracy: [0.63841644 0.72351046 0.71339531 0.73697972 0.72063173 0.7400169
#  0.7359233  0.74036024 0.72652123]
# The best accuracy was with 0.7403602366363828 with k= 8

# %%
plt.plot(range(1,Ks),mean_acc,'b')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Nabors (K)')
plt.tight_layout()
plt.show()

# %%
neigh = KNeighborsClassifier(n_neighbors = 8).fit(X_train,y_train)
neigh
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=8, p=2,
#            weights='uniform')

# %%
from sklearn.tree import DecisionTreeClassifier
loanTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
clf=loanTree.fit(X_train,y_train)
predTree = loanTree.predict(X_test)
print("DecisionTrees's accuracy: ", metrics.accuracy_score(y_test, predTree))
loanTree
# Out:
# DecisionTrees's accuracy:  0.7531956475808156
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(X_train, y_train)
yhat = clf.predict(X_test)
print("SVM's accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVM's accuracy:  0.7522712867103317

# %%
from sklearn.linear_model import LogisticRegression
# training
LR = LogisticRegression(C=0.01).fit(X_train,y_train)
LR
yhat = LR.predict(X_test)
yhat_prob = LR.predict_proba(X_test)
print('accuracy:',metrics.accuracy_score(y_test, yhat))
# Out:
# accuracy: 0.7239066131417705
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
yhat_knn = neigh.predict(X_test)
jaccard_knn = jaccard_similarity_score(y_test, yhat_knn)
print("KNN Jaccard index: ", jaccard_knn)

f1_score_knn = f1_score(y_test, yhat_knn, average='weighted')
print("KNN F1-score: ", f1_score_knn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-a5360e72b733> in <module>
#       1 yhat_knn = neigh.predict(X_test)
# ----> 2 jaccard_knn = jaccard_similarity_score(y_test, yhat_knn)
#       3 print("KNN Jaccard index: ", jaccard_knn)
#       4
#       5 f1_score_knn = f1_score(y_test, yhat_knn, average='weighted')
#
# NameError: name 'jaccard_similarity_score' is not defined

# %%
yhat_dt = loanTree.predict(X_test)
jaccard_dt = jaccard_similarity_score(y_test, yhat_dt)
print("DT Jaccard index: ", jaccard_dt)
f1_score_dt = f1_score(y_test, yhat_dt, average='weighted')
print("DT F1-score: ", f1_score_dt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-dd02d9e274c5> in <module>
#       1 yhat_dt = loanTree.predict(X_test)
# ----> 2 jaccard_dt = jaccard_similarity_score(y_test, yhat_dt)
#       3 print("DT Jaccard index: ", jaccard_dt)
#       4 f1_score_dt = f1_score(y_test, yhat_dt, average='weighted')
#       5 print("DT F1-score: ", f1_score_dt)
#
# NameError: name 'jaccard_similarity_score' is not defined

# %%
yhat_svm = clf.predict(X_test)
jaccard_svm = jaccard_similarity_score(y_test, yhat_svm)
print("SVM Jaccard index: ", jaccard_svm)
f1_score_svm = f1_score(y_test, yhat_svm, average='weighted')
print("SVM F1-score: ", f1_score_svm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-b4303255150c> in <module>
#       1 yhat_svm = clf.predict(X_test)
# ----> 2 jaccard_svm = jaccard_similarity_score(y_test, yhat_svm)
#       3 print("SVM Jaccard index: ", jaccard_svm)
#       4 f1_score_svm = f1_score(y_test, yhat_svm, average='weighted')
#       5 print("SVM F1-score: ", f1_score_svm)
#
# NameError: name 'jaccard_similarity_score' is not defined

# %%
yhat_lg = LR.predict(X_test)
yhat_lg_prob = LR.predict_proba(X_test)
jaccard_lg = jaccard_similarity_score(y_test, yhat_lg)
print("LR Jaccard index: ", jaccard_lg)
f1_score_lg = f1_score(y_test, yhat_lg, average='weighted')
print("LR F1-score: ", f1_score_lg)
logloss_lg = log_loss(y_test, yhat_lg_prob)
print("LR log loss: ", logloss_lg)
